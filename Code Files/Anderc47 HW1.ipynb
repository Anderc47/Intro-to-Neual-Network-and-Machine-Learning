# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.append("C:\\Users\\callu\\.mlrefined")

from mlrefined_libraries import math_optimization_library as optlib
static_plotter = optlib.static_plotter.Visualizer();

print('Imported')
# Out:
# Imported

# %%
# random search function
def random_search(g,alpha_choice,max_its,w,num_samples):
    # run random search
    w_history = [w]         # container for w history
    cost_history = [g(w)]           # container for corresponding cost function history
    alpha = 0
    
    
    d_list = []
    
    for k in range(1,max_its+1):
        # check if diminishing steplength rule used
        if alpha_choice == 'diminishing':
            alpha = 1/float(k)
        else:
            alpha = alpha_choice
        n = 0
        while n < num_samples:
            n = n + 1
            direction = np.random.randn(np.size(w))
            norm = np.linalg.norm(direction)    
            d_norm = direction/norm
            d_norm_alpha =d_norm*alpha
            d_list.append(alpha*d_norm_alpha)
            
        w_candidates = w + d_list
        g_candidates = np.array([g(w) for w in w_candidates])
        w_index = np.argmin(g_candidates)
        
        if g(w_candidates[w_index]) < g(w):
            w = w_candidates[w_index]
            w_history.append(w)
            cost_history.append(g(w))
      

                
        
    return w_history,cost_history

# %% [markdown]
# # 1.2: (alpha = 1) test and plot w_history and cost_history

# %%
g = lambda w: np.dot(w.T,w) + 2
alpha_choice = 1; w = np.array([3,4]); num_samples = 1000; max_its = 5;

print('alpha = 1:\n')

list_w, list_cost = random_search(g,alpha_choice,max_its,w,num_samples)
static_plotter.plot_cost_histories([list_cost],start = 0,points = True)
print('cost is:\n',list_cost,'\n w is:\n',list_w)
# Out:
# alpha = 1:
# cost is:
#  [27, 18.000155810827962, 11.000194048729586, 6.000211333382174, 3.000126712147171, 2.0000143187848125]
#  w is:
#  [array([3, 4]), array([2.40447518, 3.19666309]), array([1.80687574, 2.39486829]), array([1.2004259 , 1.59974654]), array([0.60282646, 0.79795173]), array([-0.00297624,  0.00233683])]

# %% [markdown]
# # 1.3: (alpha = 0.3) test and plot w_history and cost_history

# %%
g = lambda w: np.dot(w.T,w) + 2
alpha_choice = 0.3; w = np.array([3,4]); num_samples = 1000; max_its = 5;
list_w, list_cost = random_search(g,alpha_choice,max_its,w,num_samples)
print('alpha = 0.3:\n')
static_plotter.plot_cost_histories([list_cost],start = 0,points = True)
print('cost is:\n',list_cost,'\n:w is:\n',list_w)
# Out:
# alpha = 0.3:
# cost is:
#  [27, 26.108100585915853, 25.232401171831704, 24.372901757704675, 23.529601746770965, 22.70250173583726]
# :w is:
#  [array([3, 4]), array([2.94591788, 3.92806166]), array([2.89183576, 3.85612333]), array([2.83775364, 3.78418499]), array([2.78374177, 3.71219389]), array([2.7297299 , 3.64020279])]

# %% [markdown]
# # 1.4: 1st alpha = 1, then alpha = 1/k, plot cost history for both
#         make a contour of g(w) and overlay the w_history

# %%
g = lambda w: 100*((w[1])-(w[0]**2))**2+((w[0])-1)**2
w=np.array([-2,2]); max_its=50; num_samples=1000; alpha_choice = 1;
list_w_1, list_cost_1 = random_search(g,alpha_choice,max_its,w,num_samples)

alpha_choice = 'diminishing'
list_w_2, list_cost_2 = random_search(g,alpha_choice,max_its,w,num_samples)
'''
plt.plot(list_cost_1,color='red')
plt.title('cost plot for alpha=1')
plt.ylabel('cost')
plt.xlabel('# diminishing directions')
plt.show()
plt.plot(list_cost_2)
plt.title('cost plot for alpha=1/k')
plt.ylabel('cost')
plt.xlabel('# diminishing directions')
plt.show()

'''
#Tried to overlay but it was too hard to see both lines as they overlapped
#print(list_w_2)
print('alpha=1 w= \t',list_w_1[-1],'\nalpha=1/k w= \t',list_w_2[-1])
static_plotter.plot_cost_histories([list_cost_1],start = 0,points = True)
static_plotter.plot_cost_histories([list_cost_2],start = 0,points = True)
static_plotter.two_input_surface_contour_plot(g,list_w_1,view = [10,30],xmin = -3, xmax = 3, ymin = -2, ymax = 3)
static_plotter.two_input_surface_contour_plot(g,list_w_2,view = [10,30],xmin = -3, xmax = 3, ymin = -2, ymax = 3)
# Out:
# alpha=1 w= 	 [0.8530693  0.72563024]
# alpha=1/k w= 	 [0.99995928 0.99991706]
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# # 1.5: Check random search with new g(w)
#     global min at  (0.0898, −0.7126) and (−0.0898, 0.7126)

# %%
g = lambda w: (4-2.1*(w[0])**2+((w[0])**4)/3)*(w[0])**2+(w[0])*(w[1])+(-4+4*(w[1])**2)*(w[1])**2
alpha_choice = 'diminishing'; w = np.array([-2.5,2.5]); num_samples = 1000; max_its = 50;
list_w_1, cost_history_1 = random_search(g,alpha_choice,max_its,w,num_samples)
static_plotter.plot_cost_histories([cost_history_1],start = 0,points = True)
print('alpha=1/k w= \t',list_w_2[-1])
alpha_choice = 1
list_w_2, cost_history_2 = random_search(g,alpha_choice,max_its,w,num_samples)
static_plotter.plot_cost_histories([cost_history_2],start = 0,points = True)
print('alpha=1 w= \t',list_w_2[-1])
# Out:
# alpha=1/k w= 	 [-0.07548431  0.68279882]
# alpha=1 w= 	 [-0.07598893  0.68145853]

# %% [markdown]
# # Exercise 2: Curse of Dimensionality

# %% [markdown]
# need w0 = (1,0,..) -> N amount of times
# N = 0..25
# number of directions (P) = [10,100,1000,10000]
# search if the direction is descending
# count number of descending directions for each dimension increase
# plot fracrtion of directions/P for each P

# %%
def curse_dim(g,alpha_choice,w,num_samples):
    alpha = 0
    d_count = 0  
    d_list = []
    
    # check if diminishing steplength rule used
    if alpha_choice == 'diminishing':
        alpha = 1/float(k)
    else:
        alpha = alpha_choice
    n = 0
    
    while n < num_samples:
        n = n + 1
        direction = np.random.randn(np.size(w))
        norm = np.linalg.norm(direction)    
        d_norm = direction/norm
        d_norm_alpha =d_norm*alpha
        d_list.append(alpha*d_norm_alpha)

    w_candidates = w + d_list
    g_candidates = np.array([g(w) for w in w_candidates])
    
    for i in range(np.size(g_candidates)):
        
        if g_candidates[i]<g(w):
            d_count = d_count+1
    
    return d_count/num_samples

# %%
g = lambda w: np.dot(w.T,w) + 2
alpha_choice = 1; max_its = 2; num_samples = [10,100,1000,10000];
x_axis = 'N'

for k in range(np.size(num_samples)):
    w = np.array([1])
    P = num_samples[k]
    print('Sample Size',P,':')
    dim_d = []
    for N in range(25):
               
        dim_d.append(100*curse_dim(g,alpha_choice,w,P))
        w = np.append(w,0)
    plt.scatter(np.arange(0,25,1),dim_d)
    plt.title("descending directions vs dimension")
    plt.xlabel("N")
    plt.ylabel("#dim/P*100")
    plt.show()
#the plt.xlabel() did not work for some reason
# Out:
# Sample Size 10 :
# Sample Size 100 :
# Sample Size 1000 :
# Sample Size 10000 :

# %% [markdown]
# # Exercise 3: Coordinate Search and Coordinate Descent

# %% [markdown]
# 3.1: Coordinate_search and coordinate_descent

# %%
def coordinate_search(g,alpha_choice,max_its,w):
    # run random search
    w_history = [w]         # container for w history
    cost_history = [g(w)]           # container for corresponding cost function history
    alpha = 0
    
    direction_plus = np.eye(np.size(w),np.size(w))
    direction_minus = -np.eye(np.size(w),np.size(w))
    directions = np.concatenate((direction_plus,direction_minus),axis=0)
    
    for k in range(1,max_its+1):
        # check if diminishing steplength rule used
        if alpha_choice == 'diminishing':
            alpha = 1/float(k)
        else:
            alpha = alpha_choice
              
        w_candidates = w + alpha*directions
        
        g_candidates = np.array([g(w) for w in w_candidates])
        
        w_index = np.argmin(g_candidates)
        
        if g(w_candidates[w_index]) < g(w):
            w = w_candidates[w_index]
            
        w_history.append(w)
        cost_history.append(g(w))              
        
    return w_history,cost_history

# %%
def coordinate_descent(g,alpha_choice,max_its,w):
    # run random search
    w_history = [w]         # container for w history
    cost_history = [g(w)]           # container for corresponding cost function history
    alpha = 0
    
    N = np.size(w)
        
    for k in range(1,max_its+1):
        # check if diminishing steplength rule used
        if alpha_choice == 'diminishing':
            alpha = 1/float(k)
        else:
            alpha = alpha_choice
       
        c = np.random.permutation(N)

        cost = g(w)
        
        for n in range(N):
            direction = np.zeros((N,1)).flatten()
            direction[c[n]] = 1
            
            evals = [g(w + alpha*direction)]
            evals.append(g(w-alpha*direction))
            evals = np.array(evals)
            
            w_index = np.argmin(evals)

            if evals[w_index] < g(w):
                w = w + ((-1)**(w_index))*alpha*direction
                w_history.append(w)
                cost_history.append(g(w))

                
        
    return w_history,cost_history

# %% [markdown]
# 3.2: Compare coordinate descent to coordinate search

# %%
g = lambda w: 0.26*((w[0])**2+(w[1])**2)-(0.48*(w[0])*(w[1]))
alpha_choice = 'diminishing'; w = np.array([3,4]); max_its = 40;

list_w_search, list_cost_1 = coordinate_search(g,alpha_choice,max_its,w)
list_w_descent, list_cost_2 = coordinate_descent(g,alpha_choice,max_its,w)

static_plotter.compare_runs_contour_plots(g,[list_w_search,list_w_descent],xmin = -1.5,xmax = 4.5,ymin = -1.5,ymax = 4.5,num_contours = 30)
static_plotter.plot_cost_histories([list_cost_1,list_cost_2],start = 0,points = False,labels = ['coordinate search','coordinate descent'])

print('coordinate search ended at g(',list_w_search[-1],')=',list_cost_1[-1])
print('coordinate descent ended at g(',list_w_descent[-1],')=',list_cost_2[-1])
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...
